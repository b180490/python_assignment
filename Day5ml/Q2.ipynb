# %% [markdown]
# Consider following datasets and do PCA on each datasets.
#
# Datasets: framingham_std.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("framingham_std.csv")
df
# Out:
#       Unnamed: 0      male       age  education  currentSmoker  cigsPerDay  \
# 0              0  1.119755 -1.232580   1.975209      -0.978364   -0.757169
# 1              1 -0.893053 -0.414905   0.019249      -0.978364   -0.757169
# 2              2  1.119755 -0.181283  -0.958730       1.022114    0.920689
# 3              3 -0.893053  1.337256   0.997229       1.022114    1.759618
# 4              4 -0.893053 -0.414905   0.997229       1.022114    1.172368
# ...          ...       ...       ...        ...            ...         ...
# 3653        3653  1.119755  0.052338  -0.958730       1.022114   -0.673276
# 3654        3654  1.119755  0.169149   0.997229       1.022114    2.850225
# 3655        3655 -0.893053  0.285960   0.019249      -0.978364   -0.757169
# 3656        3656  1.119755 -1.115769   0.997229      -0.978364   -0.757169
# 3657        3657 -0.893053 -1.232580   0.997229       1.022114    1.759618
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0          male           age     education  currentSmoker  \
# count  3658.00000  3.658000e+03  3.658000e+03  3.658000e+03   3.658000e+03
# mean   1828.50000  1.573372e-16 -2.330922e-16  9.712175e-19  -4.273357e-17
# std    1056.11797  1.000137e+00  1.000137e+00  1.000137e+00   1.000137e+00
# min       0.00000 -8.930526e-01 -2.050255e+00 -9.587302e-01  -9.783641e-01
# 25%     914.25000 -8.930526e-01 -8.821476e-01 -9.587302e-01  -9.783641e-01
# 50%    1828.50000 -8.930526e-01 -6.447261e-02  1.924946e-02  -9.783641e-01
# 75%    2742.75000  1.119755e+00  7.532023e-01  9.972291e-01   1.022114e+00
# max    3657.00000  1.119755e+00  2.388552e+00  1.975209e+00   1.022114e+00
#
#          cigsPerDay        BPMeds  prevalentStroke  prevalentHyp  \
# count  3.658000e+03  3.658000e+03     3.658000e+03  3.658000e+03
# mean   2.622287e-17  6.992766e-17    -5.827305e-18 -2.719409e-17
# std    1.000137e+00  1.000137e+00     1.000137e+00  1.000137e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3658 entries, 0 to 3657
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3658 non-null   int64
#  1   male             3658 non-null   float64
#  2   age              3658 non-null   float64
#  3   education        3658 non-null   float64
#  4   currentSmoker    3658 non-null   float64
#  5   cigsPerDay       3658 non-null   float64
#  6   BPMeds           3658 non-null   float64
#  7   prevalentStroke  3658 non-null   float64
#  8   prevalentHyp     3658 non-null   float64
#  9   diabetes         3658 non-null   float64
#  10  totChol          3658 non-null   float64
#  11  sysBP            3658 non-null   float64
#  12  diaBP            3658 non-null   float64
#  13  BMI              3658 non-null   float64
#  14  heartRate        3658 non-null   float64
#  15  glucose          3658 non-null   float64
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose'],
#       dtype='object')

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=1)

pca.fit(df)

new_component = pca.transform(df)

df['pc'] = new_component

df
# Out:
#           male       age  education  currentSmoker  cigsPerDay    BPMeds  \
# 0     1.119755 -1.232580   1.975209      -0.978364   -0.757169 -0.176901
# 1    -0.893053 -0.414905   0.019249      -0.978364   -0.757169 -0.176901
# 2     1.119755 -0.181283  -0.958730       1.022114    0.920689 -0.176901
# 3    -0.893053  1.337256   0.997229       1.022114    1.759618 -0.176901
# 4    -0.893053 -0.414905   0.997229       1.022114    1.172368 -0.176901
# ...        ...       ...        ...            ...         ...       ...
# 3653  1.119755  0.052338  -0.958730       1.022114   -0.673276 -0.176901
# 3654  1.119755  0.169149   0.997229       1.022114    2.850225 -0.176901
# 3655 -0.893053  0.285960   0.019249      -0.978364   -0.757169 -0.176901
# 3656  1.119755 -1.115769   0.997229      -0.978364   -0.757169 -0.176901
# 3657 -0.893053 -1.232580   0.997229       1.022114    1.759618 -0.176901
#
#       prevalentStroke  prevalentHyp  diabetes   totChol     sysBP     diaBP  \
# ...
