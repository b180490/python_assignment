# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("claimants.csv")
df
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# ...        ...     ...       ...       ...     ...     ...
# 1335         1     0.0       1.0       0.0     NaN   0.576
# 1336         0     1.0       1.0       0.0    46.0   3.705
# 1337         1     1.0       1.0       0.0    39.0   0.099
# 1338         0     1.0       0.0       0.0     8.0   3.177
# 1339         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 6 columns]

# %%
df.head(5)
# Out:
#    ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0         0     0.0       1.0       0.0    50.0  34.940
# 1         1     1.0       0.0       0.0    18.0   0.891
# 2         1     0.0       1.0       0.0     5.0   0.330
# 3         0     0.0       1.0       1.0    31.0   0.037
# 4         1     0.0       1.0       0.0    30.0   0.038

# %%
df.tail(5)
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 1335         1     0.0       1.0       0.0     NaN  0.576
# 1336         0     1.0       1.0       0.0    46.0  3.705
# 1337         1     1.0       1.0       0.0    39.0  0.099
# 1338         0     1.0       0.0       0.0     8.0  3.177
# 1339         1     1.0       1.0       0.0    30.0  0.688

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ATTORNEY  1340 non-null   int64
#  1   CLMSEX    1328 non-null   float64
#  2   CLMINSUR  1299 non-null   float64
#  3   SEATBELT  1292 non-null   float64
#  4   CLMAGE    1151 non-null   float64
#  5   LOSS      1340 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 62.9 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# ...        ...     ...       ...       ...     ...     ...
# 1335         1     0.0       1.0       0.0     NaN   0.576
# 1336         0     1.0       1.0       0.0    46.0   3.705
# 1337         1     1.0       1.0       0.0    39.0   0.099
# 1338         0     1.0       0.0       0.0     8.0   3.177
# 1339         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 6 columns]>

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# ...        ...     ...       ...       ...     ...     ...
# 1335         1     0.0       1.0       0.0     NaN   0.576
# 1336         0     1.0       1.0       0.0    46.0   3.705
# 1337         1     1.0       1.0       0.0    39.0   0.099
# 1338         0     1.0       0.0       0.0     8.0   3.177
# 1339         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 6 columns]>

# %%
plt.scatter(df['CLMINSUR'],df['LOSS'])

plt.xlabel('CLMINSUR')
plt.ylabel('LOSS')



plt.title('CLMINSUR v/s LOSS')
# Out:
# Text(0.5, 1.0, 'CLMINSUR v/s LOSS')

# %%
plt.bar(df['CLMINSUR'],df['LOSS'])

plt.xlabel('CLMINSUR')
plt.ylabel('LOSS')



plt.title('CLMINSUR v/s LOSS')
plt.show()

# %%
plt.hist(df['LOSS'])


plt.ylabel('LOSS')



plt.title('CLMINSUR v/s LOSS')
plt.show()

# %%
df.corr()
# Out:
#           ATTORNEY    CLMSEX  CLMINSUR  SEATBELT    CLMAGE      LOSS
# ATTORNEY  1.000000  0.079674  0.079439 -0.057189  0.010680 -0.219715
# CLMSEX    0.079674  1.000000  0.066413 -0.015024 -0.023195 -0.027611
# CLMINSUR  0.079439  0.066413  1.000000  0.021154  0.049493  0.005821
# SEATBELT -0.057189 -0.015024  0.021154  1.000000 -0.027992  0.111189
# CLMAGE    0.010680 -0.023195  0.049493 -0.027992  1.000000  0.064612
# LOSS     -0.219715 -0.027611  0.005821  0.111189  0.064612  1.000000

# %%
df.cov()
# Out:
#           ATTORNEY    CLMSEX  CLMINSUR  SEATBELT      CLMAGE        LOSS
# ATTORNEY  0.250061  0.019792  0.011508 -0.003702    0.108308   -1.168687
# CLMSEX    0.019792  0.246736  0.009580 -0.000970   -0.233741   -0.146498
# CLMINSUR  0.011508  0.009580  0.083910  0.000794    0.296904    0.018181
# SEATBELT -0.003702 -0.000970  0.000794  0.016751   -0.075606    0.155671
# CLMAGE    0.108308 -0.233741  0.296904 -0.075606  412.270714   13.433106
# LOSS     -1.168687 -0.146498  0.018181  0.155671   13.433106  113.143709
